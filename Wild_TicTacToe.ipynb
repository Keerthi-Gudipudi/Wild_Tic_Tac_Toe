# %% [markdown]
# Mini-Project 4 (Part II): Solving Wild Tic-Tac-Toe Using Minimax<a href="#Mini-Project-4-(Part-II):-Solving-Wild-Tic-Tac-Toe-Using-Minimax" class="anchor-link">¶</a>
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# #### CSC 215 Artificial Intelligence (Fall 2020)<a href="#CSC-215-Artificial-Intelligence-(Fall-2020)" class="anchor-link">¶</a>
#
# #### Dr. Haiquan Chen, California State University, Sacramento<a href="#Dr.-Haiquan-Chen,-California-State-University,-Sacramento" class="anchor-link">¶</a>
#
# In \[1\]:
#
#     import random
#     import time
#
#     current = []
#
#
#     def show(board, player):
#         print(player, ":\n")
#         for i in range(3):
#             for j in range(9):
#                 if j // 3 == i:
#                     print(" ", board[j], end="  |")
#             print()
#             print("------------------")
#
#
#     def check_line(char, pos1, pos2, pos3):
#         return pos1 == pos2 == pos3 == char
#
#
#     def check_all(board, char):
#         if check_line(char, board[0], board[1], board[2]):
#             return True
#         elif check_line(char, board[3], board[4], board[5]):
#             return True
#         elif check_line(char, board[6], board[7], board[8]):
#             return True
#         elif check_line(char, board[0], board[3], board[6]):
#             return True
#         elif check_line(char, board[1], board[4], board[7]):
#             return True
#         elif check_line(char, board[2], board[5], board[8]):
#             return True
#         elif check_line(char, board[0], board[4], board[8]):
#             return True
#         elif check_line(char, board[2], board[4], board[6]):
#             return True
#         else:
#             return False
#
#
#     def check_draw(board):
#         return set(board) == {"o", "x"}
#
#
#     def check_game_over(board, player):
#         if check_all(board, "x") or check_all(board, "o"):
#             if player == "P1":
#                 return -10          # this should be -10 not 10
#             elif player == "P2":
#                 return 10           # this should be 10 not -10
#         elif check_draw(board):
#             return 0
#         else:
#             return False
#
#
#     def minimax(board, player,middleCellFirst,count):
#         global current
#         current_score = check_game_over(board, player)
#
#         if current_score is not False:
#             return current_score
#
#         scores = []
#         symbols =["x","o"]
#         if player=="P1":
#             nextplayer="P2"
#         elif player=="P2":
#             nextplayer="P1"
#         #p1_win = False
#         #p2_win = False
#         temp_boards = []
#         for j in symbols:
#             for i in range(9):
#         # check all possible moves.
#
#                 if board[i] != i:
#                     continue
#                 if player=="P1" and i==4 and middleCellFirst==False and count==0:
#                     continue
#                 current_board = board.copy()
#                 current_board[i] = j
#                 temp_boards.append(current_board)
#                 current_score=minimax(current_board,nextplayer,middleCellFirst,count+1)
#                 scores.append(current_score)
#         if player == "P1":
#         # Find the move with the highest score.   Add that move to current and return that score.
#             max_index = 0
#             for i in range(len(scores)):
#                 if scores[i] > scores[max_index]:
#                     max_index = i
#             current.append(temp_boards[max_index])
#             return scores[max_index]
#
#
#         elif player == "P2":
#         # Find the move with the lowest score.   Add that move to current and return that score.
#             min_index = 0
#             for i in range(len(scores)):
#                 if scores[i] < scores[min_index]:
#                     min_index = i
#             current.append(temp_boards[min_index])
#             return scores[min_index]
#
#
#
# Optimal vs Optimal<a href="#Optimal-vs-Optimal" class="anchor-link">¶</a>
# -------------------------------------------------------------------------
#
# In \[11\]:
#
#     def optimal_vs_optimal(middleCellFirst):
#         global current
#         board = [0, 1, 2, 3, 4, 5, 6, 7, 8]
#         current = []
#         print("Player 1 and Player 2 Both play optimally.\n")
#         show(board, "Board")
#         curr = ["P1", "P2"]
#         i = 0
#         while True:
#             count=0
#             print()
#             minimax(board, curr[i],middleCellFirst,count)
#             show(current[len(current) - 1], curr[i])
#             board = current[len(current) - 1]
#             print()
#             if check_all(board, "x") or check_all(board, "o"):
#                 print(curr[i] + " Wins!")
#                 return curr[i]
#             elif check_draw(board):
#                 print("Draw!")
#                 return "Draw"
#             i = (i + 1) % 2
#
#
#     #start_time = time.time()
#     #optimal_vs_optimal()
#     #print("\nSeconds Elapsed:", time.time() - start_time)
#
# ### Middle cell as the first move<a href="#Middle-cell-as-the-first-move" class="anchor-link">¶</a>
#
# In \[3\]:
#
#     print("Player 1 selects middle cell as the firstmove.\n")
#     optimal_vs_optimal(middleCellFirst=True)
#
#     Player 1 selects middle cell as the firstmove.
#
#     Player 1 and Player 2 Both play optimally.
#
#     Board :
#
#       0  |  1  |  2  |
#     ------------------
#       3  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#     P1 :
#
#       0  |  1  |  2  |
#     ------------------
#       3  |  x  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P2 :
#
#       x  |  1  |  2  |
#     ------------------
#       3  |  x  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P1 :
#
#       x  |  1  |  2  |
#     ------------------
#       3  |  x  |  5  |
#     ------------------
#       6  |  7  |  x  |
#     ------------------
#
#     P1 Wins!
#
# Out\[3\]:
#
#     'P1'
#
# ### Middle cell not as the first move<a href="#Middle-cell-not-as-the-first-move" class="anchor-link">¶</a>
#
# In \[4\]:
#
#     print("Player 1 does not select middle cell as the firstmove.\n")
#     optimal_vs_optimal(middleCellFirst=False)
#
#     Player 1 does not select middle cell as the firstmove.
#
#     Player 1 and Player 2 Both play optimally.
#
#     Board :
#
#       0  |  1  |  2  |
#     ------------------
#       3  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#     P1 :
#
#       x  |  1  |  2  |
#     ------------------
#       3  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P2 :
#
#       x  |  1  |  2  |
#     ------------------
#       3  |  4  |  x  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P1 :
#
#       x  |  1  |  2  |
#     ------------------
#       3  |  4  |  x  |
#     ------------------
#       6  |  x  |  8  |
#     ------------------
#
#
#     P2 :
#
#       x  |  o  |  2  |
#     ------------------
#       3  |  4  |  x  |
#     ------------------
#       6  |  x  |  8  |
#     ------------------
#
#
#     P1 :
#
#       x  |  o  |  o  |
#     ------------------
#       3  |  4  |  x  |
#     ------------------
#       6  |  x  |  8  |
#     ------------------
#
#
#     P2 :
#
#       x  |  o  |  o  |
#     ------------------
#       o  |  4  |  x  |
#     ------------------
#       6  |  x  |  8  |
#     ------------------
#
#
#     P1 :
#
#       x  |  o  |  o  |
#     ------------------
#       o  |  4  |  x  |
#     ------------------
#       6  |  x  |  o  |
#     ------------------
#
#
#     P2 :
#
#       x  |  o  |  o  |
#     ------------------
#       o  |  x  |  x  |
#     ------------------
#       6  |  x  |  o  |
#     ------------------
#
#
#     P1 :
#
#       x  |  o  |  o  |
#     ------------------
#       o  |  x  |  x  |
#     ------------------
#       x  |  x  |  o  |
#     ------------------
#
#     Draw!
#
# Out\[4\]:
#
#     'Draw'
#
# Optimal vs Random<a href="#Optimal-vs-Random" class="anchor-link">¶</a>
# =======================================================================
#
# In \[12\]:
#
#     def optimal_vs_random(middleCellFirst):
#         global current
#         board = [0, 1, 2, 3, 4, 5, 6, 7, 8]
#         current = []
#         print("Player 1 plays optimally, and Player 2 plays randomly.\n")
#         show(board, "Board")
#         print()
#         curr = ["P1", "P2"]
#         i = 0
#         count=0
#         while True:
#             print()
#             if curr[i] == "P1":
#                 minimax(board, "P1",middleCellFirst,count)
#                 show(current[len(current) - 1], "P1")
#                 board = current[len(current) - 1]
#             elif curr[i] == "P2":
#                 valid_choice = [i for i in range(9) if board[i] != "x" and board[i] != "o"]
#                 ran = valid_choice[int(random.random() * len(valid_choice))]
#                 ran2 = int(random.random() * 2)
#                 if ran2 == 0:
#                     board[ran] = "x"
#                 elif ran2 == 1:
#                     board[ran] = "o"
#                 show(board, "P2")
#             print()
#             if check_all(board, "x") or check_all(board, "o"):
#                 print(curr[i] + " Wins!")
#                 return curr[i]
#             elif check_draw(board):
#                 print("Draw!")
#                 return "Draw"
#             i = (i + 1) % 2
#
#
#     #start_time = time.time()
#     #random_vs_optimal()
#     #print("\nSeconds Elapsed:", time.time() - start_time)
#
# In \[6\]:
#
#     optimal_vs_random(False)
#
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#     Board :
#
#       0  |  1  |  2  |
#     ------------------
#       3  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P1 :
#
#       x  |  1  |  2  |
#     ------------------
#       3  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P2 :
#
#       x  |  1  |  2  |
#     ------------------
#       3  |  o  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P1 :
#
#       x  |  1  |  2  |
#     ------------------
#       3  |  o  |  5  |
#     ------------------
#       6  |  7  |  x  |
#     ------------------
#
#
#     P2 :
#
#       x  |  1  |  2  |
#     ------------------
#       3  |  o  |  x  |
#     ------------------
#       6  |  7  |  x  |
#     ------------------
#
#
#     P1 :
#
#       x  |  1  |  x  |
#     ------------------
#       3  |  o  |  x  |
#     ------------------
#       6  |  7  |  x  |
#     ------------------
#
#     P1 Wins!
#
# Out\[6\]:
#
#     'P1'
#
# Random vs Optimal<a href="#Random-vs-Optimal" class="anchor-link">¶</a>
# -----------------------------------------------------------------------
#
# In \[13\]:
#
#     def random_vs_optimal(middleCellFirst):
#         global current
#         board = [0, 1, 2, 3, 4, 5, 6, 7, 8]
#         current = []
#         print("Player 1 plays randomly, and Player 2 plays optimally.\n")
#         show(board, "Board")
#         print()
#         curr = ["P1", "P2"]
#         i = 0
#         count=0
#         while True:
#             print()
#             if curr[i] == "P1":
#                 valid_choice = [i for i in range(9) if board[i] != "x" and board[i] != "o"]
#                 ran = valid_choice[int(random.random() * len(valid_choice))]
#                 ran2 = int(random.random() * 2)
#                 if ran2 == 0:
#                     board[ran] = "x"
#                 elif ran2 == 1:
#                     board[ran] = "o"
#                 show(board, "P1")
#             elif curr[i] == "P2":
#                 minimax(board, "P2",middleCellFirst,count)
#                 show(current[len(current) - 1], "P2")
#                 board = current[len(current) - 1]
#             print()
#             if check_all(board, "x") or check_all(board, "o"):
#                 print(curr[i] + " Wins!")
#                 return curr[i]
#             elif check_draw(board):
#                 print("Draw!")
#                 return "Draw"
#             i = (i + 1) % 2
#
#
#     #start_time = time.time()
#     #random_vs_optimal()
#     #print("\nSeconds Elapsed:", time.time() - start_time)
#
# In \[8\]:
#
#     random_vs_optimal(False)
#
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#     Board :
#
#       0  |  1  |  2  |
#     ------------------
#       3  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P1 :
#
#       0  |  o  |  2  |
#     ------------------
#       3  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P2 :
#
#       x  |  o  |  2  |
#     ------------------
#       3  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P1 :
#
#       x  |  o  |  2  |
#     ------------------
#       3  |  x  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#
#     P2 :
#
#       x  |  o  |  2  |
#     ------------------
#       3  |  x  |  5  |
#     ------------------
#       6  |  7  |  x  |
#     ------------------
#
#     P2 Wins!
#
# Out\[8\]:
#
#     'P2'
#
# #### Running the code multiple times for various simulations<a href="#Running-the-code-multiple-times-for-various-simulations" class="anchor-link">¶</a>
#
# #### Both players are optimal and Middle cell chosen as the first move for 50 times<a href="#Both-players-are-optimal-and-Middle-cell-chosen-as-the-first-move-for-50-times" class="anchor-link">¶</a>
#
# ##### From below results, we have observed that, if both players are optimal and Player1 makes the middlecell as the firstmove, Player1 always wins.<a href="#From-below-results,-we-have-observed-that,-if-both-players-are-optimal-and-Player1-makes-the-middlecell-as-the-firstmove,-Player1-always-wins." class="anchor-link">¶</a>
#
# In \[14\]:
#
#     p1=0
#     p2=0
#     draw=0
#     for outputs in range(50):
#         result=optimal_vs_optimal(True)
#         print("game ",outputs+1,"result:",result)
#         if result=="P1":
#             p1=p1+1
#         elif result=="P2":
#             p2=p2+1
#         else:
#             draw=draw+1
#     print("P1 won ",p1," games ,","P2 won ",p2," games , ",draw," games are draw")
#
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  1 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  2 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  3 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  4 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  5 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  6 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  7 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  8 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  9 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  10 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  11 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  12 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  13 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  14 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  15 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  16 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  17 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  18 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  19 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  20 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  21 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  22 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  23 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  24 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  25 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  26 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  27 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  28 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  29 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  30 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  31 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  32 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  33 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  34 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  35 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  36 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  37 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  38 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  39 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  40 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  41 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  42 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  43 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  44 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  45 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  46 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  47 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  48 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  49 result: P1
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#     P1 Wins!
#     game  50 result: P1
#     P1 won  50  games , P2 won  0  games ,  0  games are draw
#
# #### Both players are optimal and Middle cell not chosen as the first move for 50 times<a href="#Both-players-are-optimal-and-Middle-cell-not-chosen-as-the-first-move-for-50-times" class="anchor-link">¶</a>
#
# ##### From below results, we have observed that, if both players are optimal and Player1 does not make the middlecell as the firstmove, Game is always a draw.<a href="#From-below-results,-we-have-observed-that,-if-both-players-are-optimal-and-Player1-does-not-make-the-middlecell-as-the-firstmove,-Game-is-always-a-draw." class="anchor-link">¶</a>
#
# In \[15\]:
#
#     p1=0
#     p2=0
#     draw=0
#     for outputs in range(50):
#         result=optimal_vs_optimal(False)
#         print("game ",outputs+1,"result:",result)
#         if result=="P1":
#             p1=p1+1
#         elif result=="P2":
#             p2=p2+1
#         else:
#             draw=draw+1
#     print("P1 won ",p1," games ,","P2 won ",p2," games , ",draw," games are draw")
#
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  1 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  2 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  3 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  4 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  5 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  6 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  7 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  8 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  9 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  10 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  11 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  12 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  13 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  14 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  15 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  16 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  17 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  18 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  19 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  20 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  21 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  22 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  23 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  24 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  25 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  26 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  27 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  28 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  29 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  30 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  31 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  32 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  33 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  34 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  35 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  36 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  37 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  38 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  39 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  40 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  41 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  42 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  43 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  44 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  45 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  46 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  47 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  48 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  49 result: Draw
#     Player 1 and Player 2 Both play optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Draw!
#     game  50 result: Draw
#     P1 won  0  games , P2 won  0  games ,  50  games are draw
#
# #### Player 1 as Optimal and Player 2 as Random i.e., Optimal player making the first move for 10 times<a href="#Player-1-as-Optimal-and-Player-2-as-Random-i.e.,-Optimal-player-making-the-first-move-for-10-times" class="anchor-link">¶</a>
#
# ##### From below results, we have observed that, if Player1 is optimal and Player2 is random, Player1 always wins if it makes the first move.<a href="#From-below-results,-we-have-observed-that,-if-Player1-is-optimal-and-Player2-is-random,-Player1-always-wins-if-it-makes-the-first-move." class="anchor-link">¶</a>
#
# In \[21\]:
#
#     p1=0
#     p2=0
#     draw=0
#     for outputs in range(10):
#         result=optimal_vs_random(False)
#         print("game ",outputs+1,"result:",result)
#         if result=="P1":
#             p1=p1+1
#         elif result=="P2":
#             p2=p2+1
#         else:
#             draw=draw+1
#     print("P1 won ",p1," games ,","P2 won ",p2," games , ",draw," games are draw")
#
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#
#
#
#
#
#
#
#
#
#
#
#     P1 Wins!
#     game  1 result: P1
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#
#
#
#
#
#
#
#
#
#
#
#     P1 Wins!
#     game  2 result: P1
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P1 Wins!
#     game  3 result: P1
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#
#
#
#
#
#
#
#
#
#
#
#     P1 Wins!
#     game  4 result: P1
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#
#
#
#
#
#
#
#     P1 Wins!
#     game  5 result: P1
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#
#
#
#
#
#
#
#     P1 Wins!
#     game  6 result: P1
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#
#
#
#
#
#
#
#
#
#
#
#     P1 Wins!
#     game  7 result: P1
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#
#
#
#
#
#
#
#     P1 Wins!
#     game  8 result: P1
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#
#
#
#
#
#
#
#
#
#
#
#     P1 Wins!
#     game  9 result: P1
#     Player 1 plays optimally, and Player 2 plays randomly.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P1 Wins!
#     game  10 result: P1
#     P1 won  10  games , P2 won  0  games ,  0  games are draw
#
# #### Player1 as Random and Player2 as Optimal i.e., Optimal player making the second move for 50 times<a href="#Player1-as-Random-and-Player2-as-Optimal-i.e.,-Optimal-player-making-the-second-move-for-50-times" class="anchor-link">¶</a>
#
# ##### From below results, we have observed that, if Player1 is random and Player2 is optimal, Player2 wins most of the games if it makes the second move.<a href="#From-below-results,-we-have-observed-that,-if-Player1-is-random-and-Player2-is-optimal,-Player2-wins-most-of-the-games-if-it-makes-the-second-move." class="anchor-link">¶</a>
#
# In \[23\]:
#
#     p1=0
#     p2=0
#     draw=0
#     for outputs in range(50):
#         result=random_vs_optimal(False)
#         print("game ",outputs+1,"result:",result)
#         if result=="P1":
#             p1=p1+1
#         elif result=="P2":
#             p2=p2+1
#         else:
#             draw=draw+1
#     print("P1 won ",p1," games ,","P2 won ",p2," games , ",draw," games are draw")
#
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  1 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  2 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  3 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  4 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  5 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  6 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  7 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  8 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  9 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  10 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  11 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  12 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  13 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  14 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  15 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  16 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  17 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  18 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  19 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  20 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  21 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  22 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  23 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  24 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  25 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  26 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  27 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  28 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  29 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  30 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  31 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  32 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  33 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  34 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  35 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  36 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  37 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  38 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  39 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  40 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  41 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  42 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  43 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  44 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  45 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  46 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  47 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  48 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  49 result: P2
#     Player 1 plays randomly, and Player 2 plays optimally.
#
#
#
#
#
#
#
#
#
#
#     P2 Wins!
#     game  50 result: P2
#     P1 won  0  games , P2 won  50  games ,  0  games are draw
#
# ### You Vs Optimal<a href="#You-Vs-Optimal" class="anchor-link">¶</a>
#
# In \[24\]:
#
#     def you_vs_optimal(middleCellFirst):
#         global current
#         board = [0, 1, 2, 3, 4, 5, 6, 7, 8]
#         current = []
#         print("You play as Player 1\n")
#         show(board, "Board")
#         print()
#         curr = ["P1", "P2"]
#         i = 0
#         count=0
#         while True:
#             if curr[i] == "P1":
#                 valid_choice = [str(i) for i in range(9) if i in board]
#                 while True:
#                     cell = input("Please enter a valid cell (" + ", ".join(valid_choice) + "): ")
#                     if cell in valid_choice:
#                         break
#                 while True:
#                     character = input("Please enter a valid character (x, o): ").lower()
#                     if character in ["x", "o"]:
#                         break
#                 print()
#                 board[int(cell)] = character
#                 show(board, curr[i])
#             elif curr[i] == "P2":
#                 minimax(board, "P2",middleCellFirst,count)
#                 show(current[len(current) - 1], "P2")
#                 board = current[len(current) - 1]
#             print()
#             if check_all(board, "x") or check_all(board, "o"):
#                 print(curr[i] + " Wins!")
#                 return curr[i]
#             if check_draw(board):
#                 print("Draw!")
#                 return "Draw"
#             i = (i + 1) % 2
#
#
#     #you_vs_optimal()
#
# In \[25\]:
#
#     you_vs_optimal(False)
#
#     You play as Player 1
#
#     Board :
#
#       0  |  1  |  2  |
#     ------------------
#       3  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#     Please enter a valid cell (0, 1, 2, 3, 4, 5, 6, 7, 8): 3
#     Please enter a valid character (x, o): o
#
#     P1 :
#
#       0  |  1  |  2  |
#     ------------------
#       o  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#     P2 :
#
#       x  |  1  |  2  |
#     ------------------
#       o  |  4  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#     Please enter a valid cell (1, 2, 4, 5, 6, 7, 8): 4
#     Please enter a valid character (x, o): o
#
#     P1 :
#
#       x  |  1  |  2  |
#     ------------------
#       o  |  o  |  5  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#     P2 :
#
#       x  |  1  |  2  |
#     ------------------
#       o  |  o  |  o  |
#     ------------------
#       6  |  7  |  8  |
#     ------------------
#
#     P2 Wins!
#
# Out\[25\]:
#
#     'P2'
